# %% [markdown]
# ### formated emails to a set of users

# %%
import datetime
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import smtplib
host = "smtplib.gmail.com"
port = 587
username = "customer.py2020@gmail.com"
password = "python2020"
from_mail = username
to_list = "customer.py2020@gmail.com
class MessageUser():b
    user_details = []
    messages = []
    email_messages = []
    base_message = [ """
        Hi {name}. Thank for for the purchase on {date}.We hope you are excited about it.
                     Just as' a reminder, the cost total was ${total}.Have a great one!
                    team MM. 
                    """]
    def add_user(self,name,amount):
        name = name[0].upper() + name[1:].lower()
        amount = '%.2f'%(amount)
        detail = {
            'name' :name,
            'amount':amount,
        }
        today = datetime.date.today()
        date_text = '{today.day}/{today.month}/{today.year}'.format(today = today)
        detail['date'] = date_text
        if email is not None:
            detail["email"] = email
        self.user_details.append(detail)
    def get_details(self):
        return self.user_details
    def make_messages(self):
        if len(self.user_details) >0:
            for detail in self.get_details():
                name = detail['name']
                amount = detail['amount']
                date = detail['date']
                message = self.base_message
                new_msg = message.format(
                name = name,
                date = date,
                total = new_amount
                )
                user_email = detail.get("email")
                if user email:
                    user_data = {
                        "email":user_email,
                        "message": new_msg
                    }
                    self.email_messages.append(user_data)
                else:
                    self.make_messages.append(new_msg)
            return self.messages
        return []
    def send_email(self): 
        self.make_messages()
        if len(self.email_messages)>0:
            for detail in self.email_messages:
                user_email = detail['email']
                user_message = detail['message'
                try:
                email_connect = smtplib.SMTP(host,port)
                #email_connect.ehlo()
                email_connect.starttls(username,password)
                email_connect.login(username,password)
                the_msg = MIMEMultipart('alternative')
                the_msg['subject'] = "Billing update!"
                the_msg["from"] = from_mail
                the_msg["To"] = user_email
                #plain_text = "Testing the message"
                part_1 = NIMEText(plain_text,'plain')
                the_msg.attach(part_1)
                #print(the_msg.as_string)
                email_connect.sendmail(from_mail,[user_email] ,the_msg.as_string)
                email_connect.quite()
            except smtplib.SMTPException:
                print("error sending message")
               #  return False                            
         return True
       return False
    
        
                
        
obj = MessageUser()
obj.add_user('Thomas',45464.990,'masibomabele2015@gmail.com')
obj.add_user('Laura',6778.9909)
obj.get_details()
obj.send_email()
# Out:
#   File "<ipython-input-1-1e39604ea3ce>", line 10
#     to_list = "customer.py2020@gmail.com
#                                         ^
# SyntaxError: EOL while scanning string literal
